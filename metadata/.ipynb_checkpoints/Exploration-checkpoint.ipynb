# %%
import csv
import matplotlib.pyplot as plt
import pandas as pd
import xlrd

# %%
xl = pd.ExcelFile("metadata.xlsx")

# %%
print(xl.sheet_names)
# Out:
# ['Sheet1']

# %%
df = xl.parse('Sheet1')

# %%
df.head()
# Out:
#            Publication                 Title               Author       Date  \
# 0  National Geographic          The Big Melt        Larmer, Brook 2010-04-01
# 1  National Geographic  The Burden of Thirst      Rosenberg, Tina 2010-04-01
# 2  National Geographic        Silent Streams    Chadwick, Douglas 2010-04-01
# 3  National Geographic         Sacred Waters        Newman, Cathy 2010-04-01
# 4  National Geographic           Fresh Water  Kingsolver, Barbara 2010-04-01
#
#   Language                                                URL        Field  \
# 0    en-US  https://www.nationalgeographic.com/magazine/20...  Environment
# 1    en-US  https://www.nationalgeographic.com/magazine/20...  Environment
# 2    en-US  https://www.nationalgeographic.com/magazine/20...  Environment
# 3    en-US  https://www.nationalgeographic.com/magazine/20...  Environment
# 4    en-US  https://www.nationalgeographic.com/magazine/20...  Environment
#
# ...

# %%
# %matplotlib notebook
# distributions of readability across all current collected articles
ax = df.hist(column = ["Readability (Dejargonizer)"])
plt.title("Readability (Dejargonizer) - Rakedzon et. al 2017")
plt.axvline(95, color='r', linestyle='dashed', linewidth=1)
plt.axvline(98, color='g', linestyle='dashed', linewidth=1)

ax2 = df.hist(column= ["Readability (Flesch-Kincaid)"])
# Out:
# <img src="data:image/png;base64,..." width="658.4">
# <img src="data:image/png;base64,..." width="662.4">

# %%
df2 = df.groupby("Publication")["Readability (Dejargonizer)", "Readability (Flesch-Kincaid)"].mean()
df2
df2 = pd.DataFrame(df2)
ax3 = df2.plot.bar(rot = 30, ylim = (40, 100), color = ["maroon", "gold"])
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
df3 = df.groupby("Field")["Readability (Dejargonizer)", "Readability (Flesch-Kincaid)"].mean()
df3
df3 = pd.DataFrame(df3)
ax4 = df3.plot.bar(rot = 60, ylim = (20, 100), colormap = "plasma")
# Out:
# <img src="data:image/png;base64,..." width="982.4">
